# %%
import sympy
# %matplotlib widget

# %%
sympy.init_printing()

# %%
x = sympy.Symbol('x')

# %%
x
# Out:
# x

# %%
polynomial = (2*x + 3)**4
polynomial
# Out:
#          4
# (2⋅x + 3)

# %%
polynomial.diff(x)
# Out:
#            3
# 8⋅(2⋅x + 3)

# %%
sympy.plot(polynomial)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f_one = x / (1 + x**2)
sympy.plot(f_one)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f_two = x*sympy.sin(1/x)
sympy.plot(f_two)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f_two = x**2 * sympy.sin(1/x)
sympy.plot(f_two)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
